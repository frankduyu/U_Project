# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import sklearn

# %%
data_path = "data/cell2celltrain.csv"       # 换一下路径，看你们的存在哪儿
churn_data_df = pd.read_csv(data_path)      # 读取数据为df
churn_data_df.head(5)
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
# data preprocessing（小马，礼烨）
"""
1.Churn为标签，需要改成0（No），1（Yes）；
2.所有的值为Yes/No的列，最好都改成0/1；
3.CreditRating这一列，可以处理成只有数值的；
4.所有有Unknown这个值的列，都需要处理；
  看Unknown的占比，占比较多的话，把Unknown换成-1（如果该列没有-1这个取值）；
  如果占比较少，选取一种处理缺失值的方法，推荐KNN补缺，比较简单，而且也没那么low
5.最好把每一列和标签做一下相关系数计算，如果强相关（>0.9），需要删掉（代表该列和标签近似于一个东西，用该列数值可以直接预测标签，准确率90%+）
6.CustomerID删掉，没用，pandas自带primary key
7.还想到什么其他的话可以自由发挥
"""

# %%
# train test split（小马，礼烨）
"""
直接调sklearn里的train_test_split，7:3分？你们决定
输出：churn_train_data, churn_test_data两个DF，传给下面建模的
     churn_test_data中把Churn那列值保存为一个list：true_label，之后把Churn从churn_test_data中删掉
"""

# %%
################################################
# 建模部分（所有人都可以参加）
"""
1.备选模型：逻辑回归，KNN，SVM，kernel SVM，朴素贝叶斯，决策树，随机森林，（神经网络及其延伸，CNN，AlexNet，ResNet）
  大家挑自己想了解的感兴趣的模型做一下，括号里的是深度学习分类算法，这些都是调包就好了
2.每个模型只需要输出预测标签就好了，模型评估代码我会之后在xgboost那块写的，copy一下就好了，有了评估代码再进行调参
3.先假定训练集和预测集分别为churn_train_data, churn_test_data两个DF，进行输入
  测试代码的话可以自己先定义两个条数比较少的DF，然后等小马她们处理完了再进行全量测试
"""

# %%
# xgboost_explainer(杜宇)
"""
代码主要包含xgboost的模型建设，模型训练以及模型验证，模型验证包括：Accuracy，准召，F1-score（还有什么，大家知道的话补充一下）
以及之后的解释性分析（大家建模不需要这项，参考第一行要求就好）
"""
